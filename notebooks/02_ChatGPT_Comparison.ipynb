# %%
# !git clone https://github.com/MR-just01/open_vs_closed_LLM-
# Out:
# Cloning into 'open_vs_closed_LLM-'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 34 (delta 13), reused 20 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 36.81 KiB | 4.60 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
import os
import pandas as pd

questions = pd.read_csv("data/reasoning_questions.csv")

print(f"Total Questions: {len(questions)}")

questions.head()
print(os.getcwd())
# Out:
# Total Questions: 50
# /content/open_vs_closed_LLM-

# %% [markdown]
# # ChatGPT Evaluation
#
# The questions from `reasoning_questions.csv` were submitted to the ChatGPT web interface.
#
# The generated responses were saved as `chatgpt_results.csv`.

# %%
questions = pd.read_csv("data/reasoning_questions.csv")

# %%
chatgpt = pd.read_csv("data/chatgpt_results.csv")

chatgpt.head()
